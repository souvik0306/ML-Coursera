# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('http://cdn.sundog-soft.com/SelfDriving/CarVideos.csv')

# %%
df
# Out:
#     Video ID  Vehicle  Conditions   Time
# 0          1  Model 3  Light Rain   8:03
# 1          2  Model S  Heavy Rain   9:04
# 2          3  Model X  Light Rain  13:13
# 3          4  Model 3       Clear  15:34
# 4          5  Model 3       Clear   7:03
# 5          6  Model X       Clear   5:03
# 6          7  Model 3  Light Rain  19:45
# 7          8  Model S  Heavy Rain  21:33
# 8          9  Model 3       Clear   8:33
# 9         10  Model 3       Clear  11:53
# 10        11  Model X       Clear   8:22
# 11        12  Model X       Clear  18:43

# %%
df.head()
# Out:
#    Video ID  Vehicle  Conditions   Time
# 0         1  Model 3  Light Rain   8:03
# 1         2  Model S  Heavy Rain   9:04
# 2         3  Model X  Light Rain  13:13
# 3         4  Model 3       Clear  15:34
# 4         5  Model 3       Clear   7:03

# %%
import sweetviz
car_report = sweetviz.analyze(df)
car_report.show_html('Tesla.html')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report Tesla.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
vehicle_count = df["Vehicle"].value_counts()

# %%
vehicle_count
# Out:
# Model 3    6
# Model X    4
# Model S    2
# Name: Vehicle, dtype: int64

# %%
vehicle_count.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
new_df = df[['Vehicle','Conditions']].value_counts()

# %%
new_df
# Out:
# Vehicle  Conditions
# Model 3  Clear         4
# Model X  Clear         3
# Model 3  Light Rain    2
# Model S  Heavy Rain    2
# Model X  Light Rain    1
# dtype: int64

# %%
new_df.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Vehicle,Conditions'>

# %% [markdown]
# ### Seaborn

# %%
df_cars = pd.read_csv('http://cdn.sundog-soft.com/SelfDriving/FuelEfficiency.csv')

# %%
cars = sweetviz.analyze(df_cars)
cars.show_html('Cars.html')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Report Cars.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df_cars
# Out:
#                 Mfr Name                 Carline  Eng Displ  Cylinders  \
# 0           aston martin              Vantage V8        4.0          8
# 1    Volkswagen Group of                  Chiron        8.0         16
# 2         General Motors                CORVETTE        6.2          8
# 3         General Motors                CORVETTE        6.2          8
# 4         General Motors                CORVETTE        6.2          8
# ..                   ...                     ...        ...        ...
# 713               Toyota             4RUNNER 4WD        4.0          6
# 714               Toyota  LAND CRUISER WAGON 4WD        5.7          8
# 715               Toyota             SEQUOIA 4WD        5.7          8
# 716                Volvo                XC90 AWD        2.0          4
# 717                Volvo                XC90 AWD        2.0          4
#
#     Transmission  CityMPG  HwyMPG  CombMPG  # Gears
# 0       Auto(S8)       18      25       21        8
# ...

# %%
gears = df_cars['# Gears'].value_counts()

# %%
gears.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set()
gears.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_cars.head()
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8

# %%
sns.distplot(df_cars['CombMPG'])
# Out:
# C:\Python\Python395\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CombMPG', ylabel='Density'>

# %%
sns.pairplot(df_cars,hue='Cylinders',height=2.5)

# %%
sns.scatterplot(x='Eng Displ',y='CombMPG',data=df_cars)
# Out:
# <AxesSubplot:xlabel='Eng Displ', ylabel='CombMPG'>

# %%
sns.jointplot(x='Eng Displ',y='CombMPG',data=df_cars)

# %%
sns.lmplot(x='Eng Displ',y='CombMPG',data=df_cars)

# %%
companines = df_cars['Mfr Name'].value_counts()
companines
# Out:
# General Motors          137
# BMW                     108
# FCA US LLC               60
# Jaguar Land Rover L      55
# Porsche                  52
# Toyota                   44
# Hyundai                  42
# Honda                    33
# Nissan                   29
# Ford Motor Company       28
# Kia                      27
# Subaru                   22
# Volvo                    19
# Mercedes-Benz            18
# Ferrari                  10
# Volkswagen Group of       8
# Maserati                  8
# Mitsubishi Motors Co      7
# Rolls-Royce               4
# MAZDA                     4
# aston martin              3
# Name: Mfr Name, dtype: int64

# %%
df_cars.head()
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8

# %%
sns.barplot(x='# Gears',y='CombMPG',data=df_cars)
# Out:
# <AxesSubplot:xlabel='# Gears', ylabel='CombMPG'>

# %%
sns.set(rc={'figure.figsize':(25,5)})
map = sns.scatterplot(x='Mfr Name',y='CombMPG',data=df_cars,hue = 'CombMPG',size='CombMPG',sizes=(20,200))

# %%
ax = sns.boxplot(x='Mfr Name',y='CombMPG',
data=df_cars)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %%
swarm = sns.swarmplot(x='Mfr Name',y='CombMPG',data=df_cars)
swarm.set_xticklabels(swarm.get_xticklabels(),rotation=45)
# Out:
# C:\Python\Python395\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python\Python395\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python\Python395\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
# ...

# %%
df2 = df_cars.pivot_table(index='Cylinders',columns='Eng Displ',values='CombMPG',aggfunc='mean')
sns.heatmap(df2)
# Out:
# <AxesSubplot:xlabel='Eng Displ', ylabel='Cylinders'>

# %%
df_cars.head()
# df_cars['Transmission'].value_counts()
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8

# %%
df3 = df_cars.pivot_table(index='# Gears',columns='Cylinders',values='CombMPG',aggfunc='mean')
sns.heatmap(df3)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='# Gears'>

# %%
sns.lmplot(x='Eng Displ',y='CombMPG',data=df_cars)

# %%
sns.lmplot(x='# Gears',y='CombMPG',data=df_cars)

# %%
sns.jointplot(x='# Gears',y='CombMPG',data=df_cars)
