# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from skimage.feature import hog

# %%
import glob

no_car = glob.glob(r"D:\Machine Learning Coursera\ML-Coursera\SVM\CaltechGraz\non-vehicles\**\*.png")
print(no_car)
# Out:
# ['D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0975.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0976.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0977.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0978.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0979.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0980.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0981.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0982.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0983.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0984.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0985.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0986.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0987.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0988.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0989.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0990.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0991.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0992.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0993.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0994.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0995.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0996.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0997.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0998.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Far\\image0999.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0975.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0976.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0977.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0978.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0979.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0980.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0981.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0982.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0983.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0984.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0985.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0986.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0987.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0988.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\non-vehicles\\Left\\image0989.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\n ...

# %%
len(no_car)
# Out:
# 100

# %%
import glob

car = glob.glob(r"D:\Machine Learning Coursera\ML-Coursera\SVM\CaltechGraz\vehicles\**\*.png")
print(car)
# Out:
# ['D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0975.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0976.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0977.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0978.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0979.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0980.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0981.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0982.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0983.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0984.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0985.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0986.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0987.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0988.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0989.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0990.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0991.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0992.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0993.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0994.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0995.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0996.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0997.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0998.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Far\\image0999.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0975.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0976.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0977.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0978.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0979.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0980.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0981.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0982.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0983.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0984.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0985.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0986.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0987.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0988.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0989.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0990.png', 'D:\\Machine Learning Coursera\\ML-Coursera\\SVM\\CaltechGraz\\vehicles\\Left\\image0991.png', 'D:\\Machine Learning Coursera\\ML ...

# %%
len(car)
# Out:
# 575
